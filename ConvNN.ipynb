# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# Let the input be $\large{X \in \mathbf{R}^{H \times W \times C_{in}}}$
#
# Filter/Kernel be $\large{K \in \mathbf{R} ^ {k_h \times k_w \times C_{in}} }$ $\large{\text{ where, } K_{h}, K_{w} \text{ is smaller than input spatial dimension}}$
#
# Stride $s$
#
# Padding $p$
